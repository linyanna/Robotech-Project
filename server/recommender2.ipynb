# %%
# Based on tutorial from https://machinelearninggeek.com/spotify-song-recommender-system-in-python/
import pandas as pd
from sklearn.metrics.pairwise import sigmoid_kernel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn import preprocessing
import sys
import os
import random
import logging

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

# Select random sample: https://stackoverflow.com/questions/22258491/read-a-small-random-sample-from-a-big-csv-file-into-a-python-data-frame
# filename = "./static/tracks.csv"
n = sum(1 for line in open(filename)) - 1 #number of records in file (excludes header)
s = 1000 #desired sample size
skip = sorted(random.sample(range(1,n+1),n-s)) #the 0-indexed header will not be included in the skip list
df = pd.read_csv(filename, skiprows=skip)

# df=pd.read_csv("./static/tracks.csv", nrows=40000)

df.head()
# Out:
#                        id                                            name  \
# 0  6N1wS1e5bMOubmVtkDLNrt            Gimme a Pigfoot and a Bottle of Beer
# 1  5ibit3V15UeNAxP37fZ5Mz  Chapter 6.18 - Król Maciuś na wyspie bezludnej
# 2  74Ksfz9rsbP16lykqJ95sv                    Chapter 135 - The Unlit Lamp
# 3  5gMFh4lraF1XCYruow1cAi                                Cornet Chop Suey
# 4  1IHM1j84hSNc00dKp4rOZy                               Smoke House Blues
#
#    popularity  duration_ms  explicit  \
# 0          16       208827         0
# 1           0       133100         0
# 2           0       181940         0
# 3           1       175027         0
# 4           2       191560         0
#
#                                              artists  \
# 0                                   ['Bessie Smith']
# 1                                 ['Janusz Korczak']
# 2  ['Radclyffe Hall', 'Alice White', 'Synthesized...
# 3                 ['Louis Armstrong & His Hot Five']
# 4                              ['Jelly Roll Morton']
#
#                                           id_artists release_date  \
# 0                         ['5ESobCkc6JI4tIMxQttqeg']         1923
# 1                         ['4hLtcEEpjCmBtTnDdzRV4J']   1923-12-27
# 2  ['2OJEUmIIPsTAUjil4dOz70', '35AgMyuKAQIoMJZEp3...         1924
# 3                         ['0t4VVR2T9Sb0z3NdDdEU6S']         1925
# 4                         ['4XepUkisa56DUeA3gbjDQD']         1926
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.691   0.198    7   -11.164     0       0.0784         0.971
# 1         0.718   0.273    1   -20.341     0       0.9500         0.688
# 2         0.615   0.344    7   -16.403     0       0.9530         0.744
# 3         0.628   0.278    5    -9.357     1       0.1440         0.994
# 4         0.642   0.718    8    -5.480     1       0.0448         0.943
#
#    instrumentalness  liveness  valence    tempo  time_signature
# 0           0.00888    0.1540    0.558  103.901               4
# 1           0.00000    0.1750    0.616   95.306               3
# 2           0.00000    0.1300    0.379   74.774               4
# 3           0.13500    0.0617    0.770   97.268               4
# 4           0.73100    0.0869    0.868  123.522               4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   name              1000 non-null   object
#  2   popularity        1000 non-null   int64
#  3   duration_ms       1000 non-null   int64
#  4   explicit          1000 non-null   int64
#  5   artists           1000 non-null   object
#  6   id_artists        1000 non-null   object
#  7   release_date      1000 non-null   object
#  8   danceability      1000 non-null   float64
#  9   energy            1000 non-null   float64
#  10  key               1000 non-null   int64
#  11  loudness          1000 non-null   float64
#  12  mode              1000 non-null   int64
#  13  speechiness       1000 non-null   float64
#  14  acousticness      1000 non-null   float64
#  15  instrumentalness  1000 non-null   float64
#  16  liveness          1000 non-null   float64
#  17  valence           1000 non-null   float64
#  18  tempo             1000 non-null   float64
#  19  time_signature    1000 non-null   int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 156.4+ KB

# %%
feature_cols=['popularity','duration_ms','explicit','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','time_signature',]

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_df =scaler.fit_transform(df[feature_cols])

print(normalized_df[:2])
# Out:
# [[0.00000000e+00 1.08713271e-01 0.00000000e+00 4.90073145e-01
#   3.04985891e-01 8.18181818e-01 6.09036900e-01 0.00000000e+00
#   8.14002090e-02 9.95983927e-01 5.25000000e-05 3.50931677e-01
#   6.36548223e-01 3.21700247e-01 8.00000000e-01]
#  [0.00000000e+00 1.08685420e-01 0.00000000e+00 5.20376176e-01
#   2.22984227e-01 9.09090909e-01 7.20144983e-01 1.00000000e+00
#   7.97283177e-02 9.97991963e-01 3.61000000e-02 2.83643892e-01
#   8.51776650e-01 9.51134495e-01 8.00000000e-01]]

# %% [markdown]
# # Spotify Credentials Setup #

# %%
client_id = os.getenv("SPOTIPY_CLIENT_ID")
client_secret = os.getenv("SPOTIPY_CLIENT_SECRET")
redirect_uri = os.getenv("SPOTIPY_REDIRECT_URI")

# %%
scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

# %%
auth_manager = SpotifyClientCredentials(client_id='SPOTIPY_CLIENT_ID', client_secret='SPOTIPY_CLIENT_SECRET')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
token = util.prompt_for_user_token(scope, client_id=client_id, client_secret=client_secret, redirect_uri='https://localhost:8888/callback/')

# %%
def show_recommendations_for_track(track):
    recommendations = pd.DataFrame(columns=['Track']['Artist'])
    results = sp.recommendations(seed_tracks=[track['id']])
    for track in results['tracks']:
      recommendations = [track['name'], track['artists'][0]['name']]
    recommendations.to_csv('./solutions/recommendations.csv')

# %%
scope = 'user-top-read'
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

ranges = ['short_term', 'medium_term', 'long_term']
# attributes=['id','name','popularity','duration_ms','explicit','artists','id_artists','release_date','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','time_signature']

items = sp.current_user_top_tracks(time_range='short_term', limit=5)['items']

for i, item in enumerate(items):
    print(i, item['name'], '//', item['artists'][0]['name'])
    show_recommendations_for_track(item)
# Out:
# 0 internet crush // Jeremy Zucker 4GISsjjHTA2UyM9DY4DNgY
# Recommendation:  talk is overrated (stripped.) Jeremy Zucker
# Recommendation:  12 Hours Chris James
# Recommendation:  Miss Her (feat. Nicklas Sahl) Maximillian
# Recommendation:  wonder if she loves me JVKE
# Recommendation:  back to you Alexander Stewart
# Recommendation:  Last Minute Sam MacPherson
# Recommendation:  One Day Less Anson Seabra
# Recommendation:  What If We Never Met Chris James
# Recommendation:  fall in love JAWNY
# Recommendation:  full stop Jeremy Zucker
# Recommendation:  Love Me Like That NERIAH
# Recommendation:  Walk Out That Door Ali Gatie
# Recommendation:  Why My Love (Ain't Enough) Fly By Midnight
# Recommendation:  When You Think Of Me JP Saxe
# Recommendation:  Set For Life Noah Cyrus
# Recommendation:  Soulmate Johnny Stimson
# Recommendation:  Howling at the Moon Mike Posner
# Recommendation:  Good For Me ROSIE
# Recommendation:  Worst Day ILLENIUM
# Recommendation:  Illusion Carlie Hanson
# 1 my fault // Zeph 36WabQN781ejYiSWKQAzDD
# Recommendation:  Before The Night Is Over Kristiane
# Recommendation:  Damage You Still Do Mikayla Pasterfield
# Recommendation:  Brother Vraell
# Recommendation:  till i go red - ep version runo plum
# Recommendation:  Off my chest ELIO
# Recommendation:  Sunny Disposition Carol Ades
# Recommendation:  I Can't Feel (My Body) Ally Evenson
# Recommendation:  are you? Zeph
# Recommendation:  wish I didn't know you shy martin
# Recommendation:  Never Been in Love Gatlin
# Recommendation:  Spell Dora Jar
# Recommendation:  Winter Blues (Demo) Trafton
# Recommendation:  Sex & TV Hannah Hill
# Recommendation:  Love You Anymore Devin Kennedy
# Recommendation:  Recompose Kay Nambiar
# Recommendation:  Panic Attack khai dreams
# Recommendation:  Maybe I’m Lonely Rachel Chinouriri
# Recommendation:  putting a spin on until i found you Egg
# Recommendation:  17 Genevieve Stokes
# Recommendation:  I Think I Ben Kessler
# 2 Meant To Be // Ber 0wxGIpOZbDR4RGy1sh3XhR
# Recommendation:  Hurtless - Acoustic Dean Lewis
# Recommendation:  Is It Just Me? (feat. JP Cooper) Emily Burns
# Recommendation:  Iris Chris Lanzon
# Recommendation:  I'm Not In Love Ber
# Recommendation:  okay Avery Lynch
# Recommendation:  Princess Peach Ruth B.
# Recommendation:  counting houses Luz
# Recommendation:  The Boy From Class Haley Joelle
# Recommendation:  Getting Over You Charlie Oriain
# Recommendation:  Witness Rosie Darling
# Recommendation:  echo Alexander Stewart
# Recommendation:  2% Jenna Raine
# Recommendation:  without you with me Matt Hansen
# Recommendation:  Heather - Spotify Singles Tate McRae
# Recommendation:  Things That Don’t Exist (feat. Zachary Knowles) Sydney Rose
# Recommendation:  Overthinking - Acoustic Jake Scott
# Recommendation:  The Idea Of You Hayd
# Recommendation:  Retail Therapy ROSIE
# Recommendation:  ilym John K
# Recommendation:  i don't wanna know - acoustic GOLDHOUSE
# 3 are you? // Zeph 22sTjPna1Haei3cRLgAUh0
# Recommendation:  Bad Texter Ryan Woods
# Recommendation:  strawberry milk Zeph
# Recommendation:  Orange Julianna Joy
# Recommendation:  Japanese Worry Club
# Recommendation:  THE BOTTOM MICHELLE
# Recommendation:  How to Get Physical Magdalena Bay
# Recommendation:  itch quinnie
# Recommendation:  Homemade Holiday Babygirl
# Recommendation:  When U Saw Love ELIO
# Recommendation:  Stupid Deb Never
# Recommendation:  rendezvous Isaac Dunbar
# Recommendation:  Crush Ethel Cain
# Recommendation:  HEARTBREAKER CLUB City Girl
# Recommendation:  Masochism Ky Vöss
# Recommendation:  impossible Wasia Project
# Recommendation:  was it you, was it me? J.Y.N.
# Recommendation:  Spiracle Flower Face
# Recommendation:  home of hurt Zeph
# Recommendation:  Cypress Sarah Kinsley
# Recommendation:  f a r a w a y The Japanese House
# 4 Charlie Be Quiet! // Charlie Puth 3E9es0SK2EusrHA7IaO7Zu
# Recommendation:  Flowers Miley Cyrus
# Recommendation:  YOUTH - Acoustic Troye Sivan
# Recommendation:  Easy On Me Adele
# Recommendation:  Light Switch Charlie Puth
# Recommendation:  How Far I'll Go - From "Moana" Alessia Cara
# Recommendation:  A Thousand Years Christina Perri
# Recommendation:  Nobody Compares To You (feat. Katie Pearlman) Gryffin
# Recommendation:  Anyone Justin Bieber
# Recommendation:  i hate u, i love u (feat. olivia o'brien) gnash
# Recommendation:  Anymore JEON SOMI
# Recommendation:  Waste It On Me (feat. BTS) Steve Aoki
# Recommendation:  Talking to the Moon Bruno Mars
# Recommendation:  7 rings Ariana Grande
# Recommendation:  All Falls Down (feat. Juliander) Alan Walker
# Recommendation:  How Do You Sleep? Sam Smith
# Recommendation:  That Girl Olly Murs
# Recommendation:  Too Much To Ask Niall Horan
# Recommendation:  FOOLS Troye Sivan
# Recommendation:  Story of My Life One Direction
# Recommendation:  Paris The Chainsmokers

# %% [markdown]
# # Recommendation Time #

# %%
# Create a pandas series with song titles as indices and indices as series values 
indices = pd.Series(df.index, index=df['name']).drop_duplicates()

# Create cosine similarity matrix based on given matrix
cosine = cosine_similarity(normalized_df)

def generate_recommendation(song_title, model_type=cosine ):
    """
    Purpose: Function for song recommendations 
    Inputs: song title and type of similarity model
    Output: Pandas series of recommended songs
    """
    # Get song indices
    index=indices[song_title]
    # Get list of songs for given songs
    score=list(enumerate(model_type[indices["Carmen"]]))
    # Sort the most similar songs
    similarity_score = sorted(score,key = lambda x:x[1],reverse = True)
    # Select the top-10 recommended songs
    similarity_score = similarity_score[1:11]
    top_songs_index = [i[0] for i in similarity_score]
    # Top 10 recommended songs
    top_songs=df['name'].iloc[top_songs_index]
    return top_songs

# %%
# Create sigmoid kernel matrix based on given matrix
sig_kernel = sigmoid_kernel(normalized_df)

print("Recommended Songs:")
print(generate_recommendation("Carmen",sig_kernel).values)
# Out:
# Recommended Songs:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'Carmen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[755], line 5
#       2 sig_kernel = sigmoid_kernel(normalized_df)
#       4 print("Recommended Songs:")
# ----> 5 print(generate_recommendation("Carmen",sig_kernel).values)
#
# Cell In[754], line 14, in generate_recommendation(song_title, model_type)
#       8 """
#       9 Purpose: Function for song recommendations
#      10 Inputs: song title and type of similarity model
#      11 Output: Pandas series of recommended songs
#      12 """
#      13 # Get song indices
# ---> 14 index=indices[song_title]
#      15 # Get list of songs for given songs
#      16 score=list(enumerate(model_type[indices["Carmen"]]))
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/Documents/cs-projects/GitHub/Robotech-Project/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Carmen'
